# %%
from utilEs import Queries

# %%
q = Queries()

# %%
ts = q.random_topics()

# %%
ts
# Out:
# [u'Lisa Murkowski',
#  u'NATURAL_DISASTER_NATURAL_DISASTER',
#  u'TAX_FNCACT_OFFICIALS',
#  u'TAX_ETHNICITY',
#  u'GENERAL_HEALTH',
#  u'CoastAlaska News',
#  u'Canada',
#  u'Associated Press',
#  u'United Kingdom',
#  u'BORDER',
#  u'Dan Ortiz',
#  u'NATURAL_DISASTER',
#  u'Jennifer Bourque',
#  u'TAX_ETHNICITY_CANADIAN',
#  u'Ketchikan, Alaska, United States',
#  u'Alaska, United States',
#  u'Canadian Border Services Agency',
#  u'MEDICAL',
#  u'CLOSURE',
#  u'British Columbia',
#  u'TAX_FNCACT_SPOKESWOMAN',
#  u'TAX_FNCACT']

# %%
counts = q.get_counts(map(str, ts))

# %%
counts.sort(key=lambda topic_count: -topic_count[1])

# %%
counts
# Out:
# [('TAX_FNCACT', 24364427),
#  ('Ketchikan, Alaska, United States', 15851476),
#  ('Alaska, United States', 15851362),
#  ('United Kingdom', 15838567),
#  ('TAX_ETHNICITY', 10655895),
#  ('GENERAL_HEALTH', 5295291),
#  ('MEDICAL', 5001523),
#  ('TAX_FNCACT_OFFICIALS', 3102031),
#  ('British Columbia', 2817814),
#  ('Canadian Border Services Agency', 2074651),
#  ('NATURAL_DISASTER', 1924671),
#  ('Canada', 1568030),
#  ('CoastAlaska News', 1216599),
#  ('Associated Press', 1214719),
#  ('BORDER', 732693),
#  ('TAX_FNCACT_SPOKESWOMAN', 702253),
#  ('TAX_ETHNICITY_CANADIAN', 490461),
#  ('Dan Ortiz', 282732),
#  ('Jennifer Bourque', 197554),
#  ('CLOSURE', 177950),
#  ('Lisa Murkowski', 152106),
#  ('NATURAL_DISASTER_NATURAL_DISASTER', 23197)]

# %%
topics = q.filter_by_count(counts)

# %%
res = q.topicQuery(topics)

# %%
res
# Out:
# {'hits': 9327468,
#  'results': [{u'date': u'20150405103000',
#    u'id': u'20150405103000-407',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://wnyt.com/article/stories/S3756397.shtml?cat=300'},
#   {u'date': u'20150405170000',
#    u'id': u'20150405170000-1173',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.journalgazette.net/news/us/Canada--Border-closing-won-t-block-aid-to-small-Alaska-town-5933998'},
#   {u'date': u'20150405113000',
#    u'id': u'20150405113000-317',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://newsok.com/canada-border-closing-wont-block-aid-to-small-alaska-town/article/feed/821976'},
#   {u'date': u'20150405070000',
#    u'id': u'20150405070000-1006',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.njherald.com/story/28721934/canada-border-closing-wont-block-aid-to-small-alaska-town'},
#   {u'date': u'20150405084500',
#    u'id': u'20150405084500-1233',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://wlns.com/ap/canada-border-closing-wont-block-aid-to-small-alaska-town/'},
#   {u'date': u'20150406120000',
#    u'id': u'20150406120000-938',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.santacruzsentinel.com/general-news/20150404/canada-border-closing-wont-block-aid-to-small-alaska-town'},
#   {u'date': u'20150405114500',
#    u'id': u'20150405114500-570',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.ksro.com/news/article.aspx?id=9306304'},
#   {u'date': u'20150406083000',
#    u'id': u'20150406083000-1521',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://juneauempire.com/state/2015-04-06/canada-border-closing-wont-block-aid-hyder'},
#   {u'date': u'20150405093000',
#    u'id': u'20150405093000-1233',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.washingtonpost.com/national/canada-border-closing-wont-block-aid-to-small-alaska-town/2015/04/05/39da5b9a-db5c-11e4-bf0b-f648b95a6488_story.html'},
#   {u'date': u'20150405071500',
#    u'id': u'20150405071500-140',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.KOB.com/article/stories/S3756393.shtml?cat=600'}],
#  'took': 3863}

# %%
res1 = q.topicQuery(ts)

# %%
res1
# Out:
# {'hits': 27597312,
#  'results': [{u'date': u'20150405103000',
#    u'id': u'20150405103000-407',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://wnyt.com/article/stories/S3756397.shtml?cat=300'},
#   {u'date': u'20150405170000',
#    u'id': u'20150405170000-1173',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.journalgazette.net/news/us/Canada--Border-closing-won-t-block-aid-to-small-Alaska-town-5933998'},
#   {u'date': u'20150405113000',
#    u'id': u'20150405113000-317',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://newsok.com/canada-border-closing-wont-block-aid-to-small-alaska-town/article/feed/821976'},
#   {u'date': u'20150405070000',
#    u'id': u'20150405070000-1006',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.njherald.com/story/28721934/canada-border-closing-wont-block-aid-to-small-alaska-town'},
#   {u'date': u'20150405084500',
#    u'id': u'20150405084500-1233',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://wlns.com/ap/canada-border-closing-wont-block-aid-to-small-alaska-town/'},
#   {u'date': u'20150406120000',
#    u'id': u'20150406120000-938',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.santacruzsentinel.com/general-news/20150404/canada-border-closing-wont-block-aid-to-small-alaska-town'},
#   {u'date': u'20150405114500',
#    u'id': u'20150405114500-570',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.ksro.com/news/article.aspx?id=9306304'},
#   {u'date': u'20150406083000',
#    u'id': u'20150406083000-1521',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://juneauempire.com/state/2015-04-06/canada-border-closing-wont-block-aid-hyder'},
#   {u'date': u'20150405093000',
#    u'id': u'20150405093000-1233',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.washingtonpost.com/national/canada-border-closing-wont-block-aid-to-small-alaska-town/2015/04/05/39da5b9a-db5c-11e4-bf0b-f648b95a6488_story.html'},
#   {u'date': u'20150405071500',
#    u'id': u'20150405071500-140',
#    u'topics': [u'Lisa Murkowski',
#     u'NATURAL_DISASTER_NATURAL_DISASTER',
#     u'TAX_FNCACT_OFFICIALS',
#     u'TAX_ETHNICITY',
#     u'GENERAL_HEALTH',
#     u'CoastAlaska News',
#     u'Canada',
#     u'Associated Press',
#     u'United Kingdom',
#     u'BORDER',
#     u'Dan Ortiz',
#     u'NATURAL_DISASTER',
#     u'Jennifer Bourque',
#     u'TAX_ETHNICITY_CANADIAN',
#     u'Ketchikan, Alaska, United States',
#     u'Alaska, United States',
#     u'Canadian Border Services Agency',
#     u'MEDICAL',
#     u'CLOSURE',
#     u'British Columbia',
#     u'TAX_FNCACT_SPOKESWOMAN',
#     u'TAX_FNCACT'],
#    u'url': u'http://www.KOB.com/article/stories/S3756393.shtml?cat=600'}],
#  'took': 12268}

# %%
[r['url'] for r in res1['results']]
# Out:
# [u'http://wnyt.com/article/stories/S3756397.shtml?cat=300',
#  u'http://www.journalgazette.net/news/us/Canada--Border-closing-won-t-block-aid-to-small-Alaska-town-5933998',
#  u'http://newsok.com/canada-border-closing-wont-block-aid-to-small-alaska-town/article/feed/821976',
#  u'http://www.njherald.com/story/28721934/canada-border-closing-wont-block-aid-to-small-alaska-town',
#  u'http://wlns.com/ap/canada-border-closing-wont-block-aid-to-small-alaska-town/',
#  u'http://www.santacruzsentinel.com/general-news/20150404/canada-border-closing-wont-block-aid-to-small-alaska-town',
#  u'http://www.ksro.com/news/article.aspx?id=9306304',
#  u'http://juneauempire.com/state/2015-04-06/canada-border-closing-wont-block-aid-hyder',
#  u'http://www.washingtonpost.com/national/canada-border-closing-wont-block-aid-to-small-alaska-town/2015/04/05/39da5b9a-db5c-11e4-bf0b-f648b95a6488_story.html',
#  u'http://www.KOB.com/article/stories/S3756393.shtml?cat=600']

# %%
[r['url'] for r in res['results']]
# Out:
# [u'http://wnyt.com/article/stories/S3756397.shtml?cat=300',
#  u'http://www.journalgazette.net/news/us/Canada--Border-closing-won-t-block-aid-to-small-Alaska-town-5933998',
#  u'http://newsok.com/canada-border-closing-wont-block-aid-to-small-alaska-town/article/feed/821976',
#  u'http://www.njherald.com/story/28721934/canada-border-closing-wont-block-aid-to-small-alaska-town',
#  u'http://wlns.com/ap/canada-border-closing-wont-block-aid-to-small-alaska-town/',
#  u'http://www.santacruzsentinel.com/general-news/20150404/canada-border-closing-wont-block-aid-to-small-alaska-town',
#  u'http://www.ksro.com/news/article.aspx?id=9306304',
#  u'http://juneauempire.com/state/2015-04-06/canada-border-closing-wont-block-aid-hyder',
#  u'http://www.washingtonpost.com/national/canada-border-closing-wont-block-aid-to-small-alaska-town/2015/04/05/39da5b9a-db5c-11e4-bf0b-f648b95a6488_story.html',
#  u'http://www.KOB.com/article/stories/S3756393.shtml?cat=600']

# %%
def getRecommendations(topics):
    # The tf_string computes the term frequency of the query term
    tf_string = """_index['topics']['{}'].tf()"""
    # Sum all the occurences of each topic
    sum_frequencies_script = ' + '.join([
        tf_string.format(topic.lower()) for topic in topics
    ])
    # Normalize by the length of the 'topics' field
    script = """Math.abs(({})/Math.max(1, doc['topics'].size()) - 0.75)""".format(sum_frequencies_script)
    topics = ' '.join(topics)
    # We are creating the query as string (and not as JSON) because
    # the elasticsearch json converter escapes single quotes in the groovy script
    query = """{
        "size": 10,
        "query": {
            "function_score": {
                "query": {
                    "match": { "topics": "%s" }
                },
                "script_score" : {
                    "script" : {
                        "inline": "%s",
                        "lang": "groovy"
                    }
                }
            }
        }
    }""" % (topics, script)
    results = q.es.search(index="gdelt", body=query)
    records = [record['_source'] for record in results['hits']['hits']]
    return {
        'results': records, 
        'took': results['took'],
        'hits': results['hits']['total']
    }
